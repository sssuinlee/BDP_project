# %%
import random

import numpy as np
import pandas as pd

from matplotlib import dates
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
chunks = pd.read_json('train.jsonl', lines=True, chunksize=100_000)

# %%
train = pd.DataFrame()

# %%
for i, chunk in enumerate(chunks):
    event_dict = {
        'session': [],
        'aid':     [],
        'ts':      [],
        'type':    []
    }

    if i >= 2:
        break
    for session, events in zip(chunk['session'].tolist(), \
                               chunk['events'].tolist()):
        for event in events:
            event_dict['session'].append(session)
            event_dict['aid'].append(event['aid'])
            event_dict['ts'].append(event['ts'])
            event_dict['type'].append(event['type'])
    chunk_session = pd.DataFrame(event_dict)
    train = pd.concat([train, chunk_session])

# %%
train = train.reset_index(drop=True)

# %%
display(train)
# Out:
#           session      aid             ts    type
# 0               0  1517085  1659304800025  clicks
# 1               0  1563459  1659304904511  clicks
# 2               0  1309446  1659367439426  clicks
# 3               0    16246  1659367719997  clicks
# 4               0  1781822  1659367871344  clicks
# ...           ...      ...            ...     ...
# 10285556   199999   928064  1659336408967  clicks
# 10285557   199999   849970  1659336449078  clicks
# 10285558   199999  1052480  1659336547035  clicks
# 10285559   199999   487255  1659336561116  clicks
# 10285560   199999  1138833  1659336575075  clicks
#
# [10285561 rows x 4 columns]

# %%
train.rename(index=str, columns={'session': 'customer_id',
                                 'aid' : 'product_code',
                                 'ts' : 'time_stamp',
                                 'type' : 'event_type'}, inplace=True)

# %%
display(train)
# Out:
#           customer_id  product_code     time_stamp event_type
# 0                   0       1517085  1659304800025     clicks
# 1                   0       1563459  1659304904511     clicks
# 2                   0       1309446  1659367439426     clicks
# 3                   0         16246  1659367719997     clicks
# 4                   0       1781822  1659367871344     clicks
# ...               ...           ...            ...        ...
# 10285556       199999        928064  1659336408967     clicks
# 10285557       199999        849970  1659336449078     clicks
# 10285558       199999       1052480  1659336547035     clicks
# 10285559       199999        487255  1659336561116     clicks
# 10285560       199999       1138833  1659336575075     clicks
#
# [10285561 rows x 4 columns]

# %%
train['time_stamp'] = pd.to_datetime(train['time_stamp'], unit='ms')
display(train)
# Out:
#           customer_id  product_code              time_stamp event_type
# 0                   0       1517085 2022-07-31 22:00:00.025     clicks
# 1                   0       1563459 2022-07-31 22:01:44.511     clicks
# 2                   0       1309446 2022-08-01 15:23:59.426     clicks
# 3                   0         16246 2022-08-01 15:28:39.997     clicks
# 4                   0       1781822 2022-08-01 15:31:11.344     clicks
# ...               ...           ...                     ...        ...
# 10285556       199999        928064 2022-08-01 06:46:48.967     clicks
# 10285557       199999        849970 2022-08-01 06:47:29.078     clicks
# 10285558       199999       1052480 2022-08-01 06:49:07.035     clicks
# 10285559       199999        487255 2022-08-01 06:49:21.116     clicks
# 10285560       199999       1138833 2022-08-01 06:49:35.075     clicks
#
# [10285561 rows x 4 columns]

# %%
for customer in random.sample(range(200000), 10):
    customer_df = train[train['customer_id'] == customer]
    customer_df = customer_df.sort_values(by='time_stamp')
    fig, ax = plt.subplots(figsize=(15, 5))
    ax.set_title('Customer Session Overview')
    sns.scatterplot(x='time_stamp', y='event_type', data=customer_df, hue='event_type', ax=ax)
    plt.show()

# %%
# Percentage of orders occuring after add to cart events
train['order'] = train['event_type'].apply(lambda x: 1 if x == 'orders' else 0)
train['add_to_cart'] = train['event_type'].apply(lambda x: 1 if x == 'carts' else 0)
train['order_after_cart'] = train['order'].shift(-1) + train['add_to_cart']
train['order_after_cart'] = train['order_after_cart'].apply(lambda x: 1 if x == 2 else 0)

# %%
perc = train['order_after_cart'].value_counts(normalize=True)[1]

print(f'Percentage of orders occuring after add to cart events: {perc:.2%}')
# Out:
# Percentage of orders occuring after add to cart events: 0.63%

# %%
# Percentage of add_to_cart events occuring after click events
train['click'] = train['event_type'].apply(lambda x: 1 if x == 'clicks' else 0)
train['cart_after_click'] = train['click'].shift(-1) + train['add_to_cart']
train['cart_after_click'] = train['cart_after_click'].apply(lambda x: 1 if x == 2 else 0)

# %%
perc = train['cart_after_click'].value_counts(normalize=True)[1]

print(f'Percentage of add_to_cart events occuring after click events: {perc:.2%}')
# Out:
# Percentage of add_to_cart events occuring after click events: 5.89%

# %%
# Percentage of click events occuring after click events
train['click_after_click'] = train['click'].shift(-1) + train['click']
train['click_after_click'] = train['click_after_click'].apply(lambda x: 1 if x == 2 else 0)

# %%
perc = train['click_after_click'].value_counts(normalize=True)[1]

print(f'Percentage of click events occuring after click events: {perc:.2%}')
# Out:
# Percentage of click events occuring after click events: 83.64%

# %%
display(train)
# Out:
#           customer_id  product_code              time_stamp event_type  order  \
# 0                   0       1517085 2022-07-31 22:00:00.025     clicks      0
# 1                   0       1563459 2022-07-31 22:01:44.511     clicks      0
# 2                   0       1309446 2022-08-01 15:23:59.426     clicks      0
# 3                   0         16246 2022-08-01 15:28:39.997     clicks      0
# 4                   0       1781822 2022-08-01 15:31:11.344     clicks      0
# ...               ...           ...                     ...        ...    ...
# 10285556       199999        928064 2022-08-01 06:46:48.967     clicks      0
# 10285557       199999        849970 2022-08-01 06:47:29.078     clicks      0
# 10285558       199999       1052480 2022-08-01 06:49:07.035     clicks      0
# 10285559       199999        487255 2022-08-01 06:49:21.116     clicks      0
# 10285560       199999       1138833 2022-08-01 06:49:35.075     clicks      0
#
#           add_to_cart  order_after_cart  click  cart_after_click  \
# 0                   0                 0      1                 0
# 1                   0                 0      1                 0
# 2                   0                 0      1                 0
# 3                   0                 0      1                 0
# 4                   0                 0      1                 0
# ...               ...               ...    ...               ...
# 10285556            0                 0      1                 0
# 10285557            0                 0      1                 0
# 10285558            0                 0      1                 0
# 10285559            0                 0      1                 0
# 10285560            0                 0      1                 0
#
#           click_after_click
# 0                         1
# 1                         1
# 2                         1
# 3                         1
# 4                         1
# ...                     ...
# 10285556                  1
# 10285557                  1
# 10285558                  1
# 10285559                  1
# 10285560                  0
#
# [10285561 rows x 10 columns]

# %%
grouped_train = train.groupby('customer_id').count()

# %%
display(grouped_train)
# Out:
#              product_code  time_stamp  event_type  order  add_to_cart  \
# customer_id
# 0                     276         276         276    276          276
# 1                      32          32          32     32           32
# 2                      33          33          33     33           33
# 3                     226         226         226    226          226
# 4                      19          19          19     19           19
# ...                   ...         ...         ...    ...          ...
# 199995                 17          17          17     17           17
# 199996                 25          25          25     25           25
# 199997                154         154         154    154          154
# 199998                  2           2           2      2            2
# 199999                  9           9           9      9            9
#
#              order_after_cart  click  cart_after_click  click_after_click
# customer_id
# 0                         276    276               276                276
# 1                          32     32                32                 32
# 2                          33     33                33                 33
# 3                         226    226               226                226
# 4                          19     19                19                 19
# ...                       ...    ...               ...                ...
# 199995                     17     17                17                 17
# 199996                     25     25                25                 25
# 199997                    154    154               154                154
# 199998                      2      2                 2                  2
# 199999                      9      9                 9                  9
#
# [200000 rows x 9 columns]

# %%
grouped_train.describe()
# Out:
#         product_code     time_stamp     event_type          order  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean       51.427805      51.427805      51.427805      51.427805
# std        75.456583      75.456583      75.456583      75.456583
# min         2.000000       2.000000       2.000000       2.000000
# 25%         6.000000       6.000000       6.000000       6.000000
# 50%        19.000000      19.000000      19.000000      19.000000
# 75%        62.000000      62.000000      62.000000      62.000000
# max       495.000000     495.000000     495.000000     495.000000
#
#          add_to_cart  order_after_cart          click  cart_after_click  \
# count  200000.000000     200000.000000  200000.000000     200000.000000
# mean       51.427805         51.427805      51.427805         51.427805
# std        75.456583         75.456583      75.456583         75.456583
# min         2.000000          2.000000       2.000000          2.000000
# 25%         6.000000          6.000000       6.000000          6.000000
# 50%        19.000000         19.000000      19.000000         19.000000
# 75%        62.000000         62.000000      62.000000         62.000000
# max       495.000000        495.000000     495.000000        495.000000
#
#        click_after_click
# count      200000.000000
# mean           51.427805
# std            75.456583
# min             2.000000
# 25%             6.000000
# 50%            19.000000
# 75%            62.000000
# max           495.000000

# %%
plt.figure(figsize=(10, 5))
sns.distplot(grouped_train['product_code'], kde=False, bins=100)
plt.title('Distribution of number of products viewed by customer')
plt.xlabel('Number of products viewed')
plt.ylabel('Number of customers')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(train['event_type'], stat='percent', kde=False, bins=100)
plt.title('Distribution of event types')
plt.xlabel('Event type')
plt.ylabel('Number of events')
plt.show()

# %%
grouped_train = train.groupby('customer_id').count()
grouped_train_orders = train[train['event_type'] == 'orders'].groupby('customer_id').count().join(grouped_train, lsuffix='_orders', rsuffix='_views')   
grouped_train_orders = grouped_train_orders.drop(['product_code_views', 'time_stamp_views'], axis=1).rename(columns={'event_type_views': 'event_count'})

# %%
display(grouped_train_orders)
# Out:
#              product_code_orders  time_stamp_orders  event_type_orders  \
# customer_id
# 0                              4                  4                  4
# 3                              5                  5                  5
# 4                              1                  1                  1
# 11                             2                  2                  2
# 12                             1                  1                  1
# ...                          ...                ...                ...
# 199980                         1                  1                  1
# 199985                         4                  4                  4
# 199991                         2                  2                  2
# 199993                         3                  3                  3
# 199997                         7                  7                  7
#
#              order_orders  add_to_cart_orders  order_after_cart_orders  \
# customer_id
# 0                       4                   4                        4
# 3                       5                   5                        5
# 4                       1                   1                        1
# 11                      2                   2                        2
# 12                      1                   1                        1
# ...                   ...                 ...                      ...
# 199980                  1                   1                        1
# 199985                  4                   4                        4
# 199991                  2                   2                        2
# 199993                  3                   3                        3
# 199997                  7                   7                        7
#
#              click_orders  cart_after_click_orders  click_after_click_orders  \
# customer_id
# 0                       4                        4                         4
# 3                       5                        5                         5
# 4                       1                        1                         1
# 11                      2                        2                         2
# 12                      1                        1                         1
# ...                   ...                      ...                       ...
# 199980                  1                        1                         1
# 199985                  4                        4                         4
# 199991                  2                        2                         2
# 199993                  3                        3                         3
# 199997                  7                        7                         7
#
#              event_count  order_views  add_to_cart_views  \
# customer_id
# 0                    276          276                276
# 3                    226          226                226
# 4                     19           19                 19
# 11                    93           93                 93
# 12                     5            5                  5
# ...                  ...          ...                ...
# 199980                32           32                 32
# 199985                37           37                 37
# 199991                27           27                 27
# 199993                31           31                 31
# 199997               154          154                154
#
#              order_after_cart_views  click_views  cart_after_click_views  \
# customer_id
# 0                               276          276                     276
# 3                               226          226                     226
# 4                                19           19                      19
# 11                               93           93                      93
# 12                                5            5                       5
# ...                             ...          ...                     ...
# 199980                           32           32                      32
# 199985                           37           37                      37
# 199991                           27           27                      27
# 199993                           31           31                      31
# 199997                          154          154                     154
#
#              click_after_click_views
# customer_id
# 0                                276
# 3                                226
# 4                                 19
# 11                                93
# 12                                 5
# ...                              ...
# 199980                            32
# 199985                            37
# 199991                            27
# 199993                            31
# 199997                           154
#
# [50871 rows x 16 columns]

# %%
# plot trend between event count and event type orders
plt.figure(figsize=(10, 5))
sns.scatterplot(x=grouped_train_orders['event_count'], y=grouped_train_orders['product_code_orders'])
plt.title('Distribution of number of products ordered by customer')
plt.xlabel('Number of products viewed')
plt.ylabel('Number of products ordered')
plt.show()

# %%
display( grouped_train_orders[grouped_train_orders['product_code_orders'] < 100])
# Out:
#              product_code_orders  time_stamp_orders  event_type_orders  \
# customer_id
# 0                              4                  4                  4
# 3                              5                  5                  5
# 4                              1                  1                  1
# 11                             2                  2                  2
# 12                             1                  1                  1
# ...                          ...                ...                ...
# 199980                         1                  1                  1
# 199985                         4                  4                  4
# 199991                         2                  2                  2
# 199993                         3                  3                  3
# 199997                         7                  7                  7
#
#              order_orders  add_to_cart_orders  order_after_cart_orders  \
# customer_id
# 0                       4                   4                        4
# 3                       5                   5                        5
# 4                       1                   1                        1
# 11                      2                   2                        2
# 12                      1                   1                        1
# ...                   ...                 ...                      ...
# 199980                  1                   1                        1
# 199985                  4                   4                        4
# 199991                  2                   2                        2
# 199993                  3                   3                        3
# 199997                  7                   7                        7
#
#              click_orders  cart_after_click_orders  click_after_click_orders  \
# customer_id
# 0                       4                        4                         4
# 3                       5                        5                         5
# 4                       1                        1                         1
# 11                      2                        2                         2
# 12                      1                        1                         1
# ...                   ...                      ...                       ...
# 199980                  1                        1                         1
# 199985                  4                        4                         4
# 199991                  2                        2                         2
# 199993                  3                        3                         3
# 199997                  7                        7                         7
#
#              event_count  order_views  add_to_cart_views  \
# customer_id
# 0                    276          276                276
# 3                    226          226                226
# 4                     19           19                 19
# 11                    93           93                 93
# 12                     5            5                  5
# ...                  ...          ...                ...
# 199980                32           32                 32
# 199985                37           37                 37
# 199991                27           27                 27
# 199993                31           31                 31
# 199997               154          154                154
#
#              order_after_cart_views  click_views  cart_after_click_views  \
# customer_id
# 0                               276          276                     276
# 3                               226          226                     226
# 4                                19           19                      19
# 11                               93           93                      93
# 12                                5            5                       5
# ...                             ...          ...                     ...
# 199980                           32           32                      32
# 199985                           37           37                      37
# 199991                           27           27                      27
# 199993                           31           31                      31
# 199997                          154          154                     154
#
#              click_after_click_views
# customer_id
# 0                                276
# 3                                226
# 4                                 19
# 11                                93
# 12                                 5
# ...                              ...
# 199980                            32
# 199985                            37
# 199991                            27
# 199993                            31
# 199997                           154
#
# [50871 rows x 16 columns]

# %%
plt.figure(figsize=(10, 5))
sns.histplot(grouped_train_orders['product_code_orders'], stat='percent', kde=False, bins=100)
plt.title('Distribution of number of products ordered by customer')
plt.xlabel('Number of products ordered')
plt.ylabel('Number of customers')
plt.show()

# %%
grouped_train_clicks = train[train['event_type'] == 'clicks'].groupby('customer_id').count().join(grouped_train, lsuffix='_clicks', rsuffix='_views')   
grouped_train_clicks = grouped_train_clicks.drop(['product_code_views', 'time_stamp_views'], axis=1).rename(columns={'event_type_views': 'event_count'})

# %%
display(grouped_train_clicks)
# Out:
#              product_code_clicks  time_stamp_clicks  event_type_clicks  \
# customer_id
# 0                            255                255                255
# 1                             24                 24                 24
# 2                             32                 32                 32
# 3                            200                200                200
# 4                             15                 15                 15
# ...                          ...                ...                ...
# 199995                        17                 17                 17
# 199996                        24                 24                 24
# 199997                       119                119                119
# 199998                         2                  2                  2
# 199999                         9                  9                  9
#
#              order_clicks  add_to_cart_clicks  order_after_cart_clicks  \
# customer_id
# 0                     255                 255                      255
# 1                      24                  24                       24
# 2                      32                  32                       32
# 3                     200                 200                      200
# 4                      15                  15                       15
# ...                   ...                 ...                      ...
# 199995                 17                  17                       17
# 199996                 24                  24                       24
# 199997                119                 119                      119
# 199998                  2                   2                        2
# 199999                  9                   9                        9
#
#              click_clicks  cart_after_click_clicks  click_after_click_clicks  \
# customer_id
# 0                     255                      255                       255
# 1                      24                       24                        24
# 2                      32                       32                        32
# 3                     200                      200                       200
# 4                      15                       15                        15
# ...                   ...                      ...                       ...
# 199995                 17                       17                        17
# 199996                 24                       24                        24
# 199997                119                      119                       119
# 199998                  2                        2                         2
# 199999                  9                        9                         9
#
#              event_count  order_views  add_to_cart_views  \
# customer_id
# 0                    276          276                276
# 1                     32           32                 32
# 2                     33           33                 33
# 3                    226          226                226
# 4                     19           19                 19
# ...                  ...          ...                ...
# 199995                17           17                 17
# 199996                25           25                 25
# 199997               154          154                154
# 199998                 2            2                  2
# 199999                 9            9                  9
#
#              order_after_cart_views  click_views  cart_after_click_views  \
# customer_id
# 0                               276          276                     276
# 1                                32           32                      32
# 2                                33           33                      33
# 3                               226          226                     226
# 4                                19           19                      19
# ...                             ...          ...                     ...
# 199995                           17           17                      17
# 199996                           25           25                      25
# 199997                          154          154                     154
# 199998                            2            2                       2
# 199999                            9            9                       9
#
#              click_after_click_views
# customer_id
# 0                                276
# 1                                 32
# 2                                 33
# 3                                226
# 4                                 19
# ...                              ...
# 199995                            17
# 199996                            25
# 199997                           154
# 199998                             2
# 199999                             9
#
# [200000 rows x 16 columns]

# %%
plt.figure(figsize=(10, 5))
sns.histplot(grouped_train_clicks['product_code_clicks'], stat='percent', kde=False, bins=100)
plt.title('Distribution of number of products clicked by customer')
plt.xlabel('Number of products clicked')
plt.ylabel('Number of customers')
plt.show()

# %%
grouped_train_carts = train[train['event_type'] == 'carts'].groupby('customer_id').count().join(grouped_train, lsuffix='_carts', rsuffix='_views')
grouped_train_carts = grouped_train_carts.drop(['product_code_views', 'time_stamp_views'], axis=1).rename(columns={'event_type_views': 'event_count'})

# %%
display(grouped_train_carts)
# Out:
#              product_code_carts  time_stamp_carts  event_type_carts  \
# customer_id
# 0                            17                17                17
# 1                             8                 8                 8
# 2                             1                 1                 1
# 3                            21                21                21
# 4                             3                 3                 3
# ...                         ...               ...               ...
# 199991                        4                 4                 4
# 199992                       14                14                14
# 199993                        5                 5                 5
# 199996                        1                 1                 1
# 199997                       28                28                28
#
#              order_carts  add_to_cart_carts  order_after_cart_carts  \
# customer_id
# 0                     17                 17                      17
# 1                      8                  8                       8
# 2                      1                  1                       1
# 3                     21                 21                      21
# 4                      3                  3                       3
# ...                  ...                ...                     ...
# 199991                 4                  4                       4
# 199992                14                 14                      14
# 199993                 5                  5                       5
# 199996                 1                  1                       1
# 199997                28                 28                      28
#
#              click_carts  cart_after_click_carts  click_after_click_carts  \
# customer_id
# 0                     17                      17                       17
# 1                      8                       8                        8
# 2                      1                       1                        1
# 3                     21                      21                       21
# 4                      3                       3                        3
# ...                  ...                     ...                      ...
# 199991                 4                       4                        4
# 199992                14                      14                       14
# 199993                 5                       5                        5
# 199996                 1                       1                        1
# 199997                28                      28                       28
#
#              event_count  order_views  add_to_cart_views  \
# customer_id
# 0                    276          276                276
# 1                     32           32                 32
# 2                     33           33                 33
# 3                    226          226                226
# 4                     19           19                 19
# ...                  ...          ...                ...
# 199991                27           27                 27
# 199992               153          153                153
# 199993                31           31                 31
# 199996                25           25                 25
# 199997               154          154                154
#
#              order_after_cart_views  click_views  cart_after_click_views  \
# customer_id
# 0                               276          276                     276
# 1                                32           32                      32
# 2                                33           33                      33
# 3                               226          226                     226
# 4                                19           19                      19
# ...                             ...          ...                     ...
# 199991                           27           27                      27
# 199992                          153          153                     153
# 199993                           31           31                      31
# 199996                           25           25                      25
# 199997                          154          154                     154
#
#              click_after_click_views
# customer_id
# 0                                276
# 1                                 32
# 2                                 33
# 3                                226
# 4                                 19
# ...                              ...
# 199991                            27
# 199992                           153
# 199993                            31
# 199996                            25
# 199997                           154
#
# [94561 rows x 16 columns]

# %%
plt.figure(figsize=(10, 5))
sns.histplot(grouped_train_carts['product_code_carts'], stat='percent', kde=False, bins=100)
plt.title('Distribution of number of products added to cart by customer')
plt.xlabel('Number of products added to cart')
plt.ylabel('Number of customers')
plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.barplot(x=grouped_train_orders['product_code_orders'], y=grouped_train_clicks['product_code_clicks'])
plt.title('Distribution of number of products ordered by customer')
plt.xlabel('Number of products ordered')
plt.ylabel('Number of products clicked')
plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.barplot(x=grouped_train_orders['product_code_orders'], y=grouped_train_carts['product_code_carts'])
plt.title('Distribution of number of products ordered by customer')
plt.xlabel('Number of products ordered')
plt.ylabel('Number of products added to carts')
plt.show()
